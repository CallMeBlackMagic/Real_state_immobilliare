# %%
import requests
from bs4 import BeautifulSoup
import csv
import lxml
import numpy as np
import pandas as pd

# %%
immobiare_url = 'https://www.immobiliare.it/vendita-case/trieste-provincia/?criterio=rilevanza&pag='

# %%
real_states_about = []
x = 0
# iterating pages of the web site
def main_immobiliare(req):
    source = request.content
    soup = BeautifulSoup(source, 'lxml')
    real_states = soup.find_all("li", {"class": "nd-list__item in-realEstateResults__item"})
    number_of_real_states = len(real_states)

    def get_real_state_info(real_state):
        less_than_1000 = "⚠Element not found⚠"
        calc_per_meter = "⚠Element not found⚠"
        price = real_state.contents[0].find('li', {"class": "nd-list__item in-feat__item in-feat__item--main in-realEstateListCard__features--main"})
        if price is not None:
            price = price.text.strip()
        else:
            price = "Element not found."
        space = real_state.find('span', class_='in-mainFeatures__text')
        value_m_squared = space.find_previous_sibling(text=True).strip()
        if price != "Element not found.":
            digit_price = price.split()[1]
            new_number = ''
            for e in digit_price:
                if e == '.':
                    e = ''
                    new_number+=e
                else:
                    new_number+=e
            calc_per_meter = int(new_number)/int(value_m_squared)
            if calc_per_meter < 1000:
                less_than_1000 = 'True✅'
            else:
                less_than_1000 = 'False❌'
        real_states_about.append({"Price": price, "M**2": value_m_squared,"Satues Price per Meter":f"{less_than_1000} The price is {calc_per_meter} per Meter"})
        # iterating inside the page and applying the function on every real state
    for i in range(number_of_real_states):
        get_real_state_info(real_states[i])

# %%
for pages in range(0,57):
    x+=1
    new_immobiare_url = immobiare_url+str(x)
    request = requests.get(new_immobiare_url)
    main_immobiliare(request)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 5
#       3 new_immobiare_url = immobiare_url+str(x)
#       4 request = requests.get(new_immobiare_url)
# ----> 5 main_immobiliare(request)
#
# Cell In[32], line 37, in main_immobiliare(req)
#      35     # iterating inside the page and applying the function on every real state
#      36 for i in range(number_of_real_states):
# ---> 37     get_real_state_info(real_states[i])
#
# Cell In[32], line 29, in main_immobiliare.<locals>.get_real_state_info(real_state)
#      27     else:
#      28         new_number+=e
# ---> 29 calc_per_meter = int(new_number)/int(value_m_squared)
#      30 if calc_per_meter < 1000:
#      31     less_than_1000 = 'True✅'
#
# ValueError: invalid literal for int() with base 10: '€'

# %%
keys = real_states_about[0].keys()
with open("The italian Man", 'w', encoding='utf-8') as output_file:
        csv_writer = csv.DictWriter(output_file, fieldnames=keys)
        csv_writer.writeheader()
        csv_writer.writerows(real_states_about)
        print("File Created")
# Out:
# File Created

# %%
real_states_about
# Out:
# [{'Price': '€ 1.600.000', 'M**2': '530'},
#  {'Price': '€ 497.000', 'M**2': '92'},
#  {'Price': '€ 850.000', 'M**2': '158'},
#  {'Price': '€ 155.000', 'M**2': '110'},
#  {'Price': '€ 650.000', 'M**2': '105'},
#  {'Price': 'Element not found.', 'M**2': '156'},
#  {'Price': '€ 1.950.000', 'M**2': '333'},
#  {'Price': 'da € 155.000', 'M**2': '51'},
#  {'Price': 'Element not found.', 'M**2': '72'},
#  {'Price': '€ 790.000', 'M**2': '370'},
#  {'Price': '€ 1.250.000', 'M**2': '287'},
#  {'Price': '€ 190.000', 'M**2': '106'},
#  {'Price': 'Element not found.', 'M**2': '1.500'},
#  {'Price': '€ 114.000', 'M**2': '78'},
#  {'Price': '€ 326.000', 'M**2': '122'},
#  {'Price': '€ 89.000', 'M**2': '65'},
#  {'Price': '€ 450.000', 'M**2': '160'},
#  {'Price': '€ 330.000', 'M**2': '193'},
#  {'Price': 'da € 75.000,00', 'M**2': '99'},
#  {'Price': '€ 210.000', 'M**2': '120'},
#  {'Price': '€ 165.000', 'M**2': '89'},
#  {'Price': '€ 210.000', 'M**2': '95'},
#  {'Price': '€ 290.000', 'M**2': '105'},
#  {'Price': 'Element not found.', 'M**2': '120'},
#  {'Price': '€ 135.000', 'M**2': '95'},
#  {'Price': '€ 85.000', 'M**2': '37'},
#  {'Price': '€ 89.000', 'M**2': '37'},
#  {'Price': '€ 242.000', 'M**2': '99'},
#  {'Price': '€ 1.300.000', 'M**2': '654'},
#  {'Price': '€ 800.000', 'M**2': '275'},
#  {'Price': '€ 580.000', 'M**2': '140'},
#  {'Price': '€ 62.000', 'M**2': '35'},
#  ...]

# %%
df = pd.DataFrame(real_states_about)

# %%
df
# Out:
#             Price M**2
# 0     € 1.600.000  530
# 1       € 497.000   92
# 2       € 850.000  158
# 3       € 155.000  110
# 4       € 650.000  105
# ...           ...  ...
# 1380     € 99.000   58
# 1381    € 165.000   65
# 1382    € 295.000  145
# 1383    € 250.000  110
# 1384    € 195.000  101
#
# [1385 rows x 2 columns]

# %%
z = '€ 1.600.000'

# %%
z.split()[1]
# Out:
# '1.600.000'

# %%
price = '€ 1.600.000'
digit_price = price.split()[1]
new_number = ''
for e in digit_price:
    if e == '.':
        e = ''
        new_number+=e
    else:
        new_number+=e

# %%
new_number
# Out:
# '1600000'

# %%
1600000 / 50000
# Out:
# 32.0

# %%
new_number
# Out:
# '€ 1600000'

# %%
for e in digit_price:
    if (e == '.') or (e == '€'):
        e = ''
        new_number+=e
    else:
        new_number+=e

# %%
import requests
from bs4 import BeautifulSoup
import csv
import lxml
import numpy as np
import pandas as pd

immobiliare_url = 'https://www.immobiliare.it/vendita-case/trieste-provincia/?criterio=rilevanza&pag='
real_states_about = []
x = 0

# Iterating pages of the website
def main_immobiliare(req):
    source = req.content
    soup = BeautifulSoup(source, 'lxml')
    real_states = soup.find_all("li", {"class": "nd-list__item in-realEstateResults__item"})
    number_of_real_states = len(real_states)

    def get_real_state_info(real_state):
        less_than_1000 = "⚠ Element not found ⚠"
        calc_per_meter = "⚠ Element not found ⚠"
        price = real_state.contents[0].find('li', {"class": "nd-list__item in-feat__item in-feat__item--main in-realEstateListCard__features--main"})
        if price is not None:
            price = price.text.strip()
        else:
            price = "Element not found."
        space = real_state.find('span', class_='in-mainFeatures__text')
        value_m_squared = space.find_previous_sibling(text=True).strip().replace('€', '')  # Remove Euro symbol
        if price != "Element not found.":
            digit_price = price.split()[1]
            new_number = ''
            for e in digit_price:
                if e == '.':
                    e = ''
                else:
                    new_number += e
            calc_per_meter = int(new_number) / int(value_m_squared)
            if calc_per_meter < 1000:
                less_than_1000 = 'True ✅'
            else:
                less_than_1000 = 'False ❌'
        real_states_about.append({"Price": price, "M**2": value_m_squared, "Status Price per Meter": f"{less_than_1000} The price is {calc_per_meter} per Meter"})

    # Iterating inside the page and applying the function on every real state
    for i in range(number_of_real_states):
        get_real_state_info(real_states[i])

for page in range(0, 57):
    x += 1
    new_immobiliare_url = immobiliare_url + str(x)
    request = requests.get(new_immobiliare_url)
    main_immobiliare(request)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 52
#      50 new_immobiliare_url = immobiliare_url + str(x)
#      51 request = requests.get(new_immobiliare_url)
# ---> 52 main_immobiliare(request)
#
# Cell In[34], line 46, in main_immobiliare(req)
#      44 # Iterating inside the page and applying the function on every real state
#      45 for i in range(number_of_real_states):
# ---> 46     get_real_state_info(real_states[i])
#
# Cell In[34], line 37, in main_immobiliare.<locals>.get_real_state_info(real_state)
#      35     else:
#      36         new_number += e
# ---> 37 calc_per_meter = int(new_number) / int(value_m_squared)
#      38 if calc_per_meter < 1000:
#      39     less_than_1000 = 'True ✅'
#
# ValueError: invalid literal for int() with base 10: '€'

# %%
import requests
from bs4 import BeautifulSoup
import csv
import lxml
import numpy as np
import pandas as pd

immobiliare_url = 'https://www.immobiliare.it/vendita-case/trieste-provincia/?criterio=rilevanza&pag='
real_states_about = []
x = 0

# Iterating pages of the website
def main_immobiliare(req):
    source = req.content
    soup = BeautifulSoup(source, 'lxml')
    real_states = soup.find_all("li", {"class": "nd-list__item in-realEstateResults__item"})
    number_of_real_states = len(real_states)

    def get_real_state_info(real_state):
        less_than_1000 = "⚠ Element not found ⚠"
        calc_per_meter = "⚠ Element not found ⚠"
        price = real_state.contents[0].find('li', {"class": "nd-list__item in-feat__item in-feat__item--main in-realEstateListCard__features--main"})
        if price is not None:
            price = price.text.strip()
        else:
            price = "Element not found."
        space = real_state.find('span', class_='in-mainFeatures__text')
        value_m_squared = space.find_previous_sibling(text=True).strip().replace('€', '').replace(',', '')  # Remove Euro symbol and comma
        if price != "Element not found.":
            digit_price = price.split()[1]
            new_number = ''.join(filter(str.isdigit, digit_price))  # Keep only digits
            calc_per_meter = int(new_number) / int(value_m_squared)
            if calc_per_meter < 1000:
                less_than_1000 = 'True ✅'
            else:
                less_than_1000 = 'False ❌'
        real_states_about.append({"Price": price, "M**2": value_m_squared, "Status Price per Meter": f"{less_than_1000} The price is {calc_per_meter} per Meter"})

    # Iterating inside the page and applying the function on every real state
    for i in range(number_of_real_states):
        get_real_state_info(real_states[i])

for page in range(0, 57):
    x += 1
    new_immobiliare_url = immobiliare_url + str(x)
    request = requests.get(new_immobiliare_url)
    main_immobiliare(request)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 47
#      45 new_immobiliare_url = immobiliare_url + str(x)
#      46 request = requests.get(new_immobiliare_url)
# ---> 47 main_immobiliare(request)
#
# Cell In[35], line 41, in main_immobiliare(req)
#      39 # Iterating inside the page and applying the function on every real state
#      40 for i in range(number_of_real_states):
# ---> 41     get_real_state_info(real_states[i])
#
# Cell In[35], line 32, in main_immobiliare.<locals>.get_real_state_info(real_state)
#      30 digit_price = price.split()[1]
#      31 new_number = ''.join(filter(str.isdigit, digit_price))  # Keep only digits
# ---> 32 calc_per_meter = int(new_number) / int(value_m_squared)
#      33 if calc_per_meter < 1000:
#      34     less_than_1000 = 'True ✅'
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import requests
from bs4 import BeautifulSoup
import csv
import lxml
import numpy as np
import pandas as pd

immobiliare_url = 'https://www.immobiliare.it/vendita-case/trieste-provincia/?criterio=rilevanza&pag='
real_states_about = []
x = 0

# Iterating pages of the website
def main_immobiliare(req):
    source = req.content
    soup = BeautifulSoup(source, 'lxml')
    real_states = soup.find_all("li", {"class": "nd-list__item in-realEstateResults__item"})
    number_of_real_states = len(real_states)

    def get_real_state_info(real_state):
        less_than_1000 = "⚠ Element not found ⚠"
        calc_per_meter = "⚠ Element not found ⚠"
        price = real_state.contents[0].find('li', {"class": "nd-list__item in-feat__item in-feat__item--main in-realEstateListCard__features--main"})
        if price is not None:
            price = price.text.strip()
        else:
            price = "Element not found."
        space = real_state.find('span', class_='in-mainFeatures__text')
        value_m_squared = space.find_previous_sibling(text=True).strip().replace('€', '').replace(',', '')  # Remove Euro symbol and comma
        if price != "Element not found." and value_m_squared and value_m_squared.isdigit():
            digit_price = price.split()[1]
            new_number = ''.join(filter(str.isdigit, digit_price))  # Keep only digits
            if new_number and new_number.isdigit():
                calc_per_meter = int(new_number) / int(value_m_squared)
                if calc_per_meter < 1000:
                    less_than_1000 = 'True ✅'
                else:
                    less_than_1000 = 'False ❌'
        real_states_about.append({"Price": price, "M**2": value_m_squared, "Status Price per Meter": f"{less_than_1000} The price is {calc_per_meter} per Meter"})

    # Iterating inside the page and applying the function on every real state
    for i in range(number_of_real_states):
        get_real_state_info(real_states[i])

for page in range(0, 57):
    x += 1
    new_immobiliare_url = immobiliare_url + str(x)
    request = requests.get(new_immobiliare_url)
    main_immobiliare(request)

# %%
df = pd.DataFrame(real_states_about)

# %%
df
# Out:
#                    Price M**2  \
# 0            € 1.600.000  530
# 1              € 497.000   92
# 2              € 850.000  158
# 3              € 650.000  105
# 4     Element not found.  156
# ...                  ...  ...
# 1374           € 165.000   65
# 1375           € 295.000  145
# 1376           € 400.000  800
# 1377           € 250.000  110
# 1378           € 195.000  101
#
#                                  Status Price per Meter
# 0      False ❌ The price is 3018.867924528302 per Meter
# 1      False ❌ The price is 5402.173913043478 per Meter
# 2     False ❌ The price is 5379.7468354430375 per Meter
# 3      False ❌ The price is 6190.476190476191 per Meter
# 4     ⚠ Element not found ⚠ The price is ⚠ Element n...
# ...                                                 ...
# 1374  False ❌ The price is 2538.4615384615386 per Meter
# 1375  False ❌ The price is 2034.4827586206898 per Meter
# 1376                True ✅ The price is 500.0 per Meter
# 1377  False ❌ The price is 2272.7272727272725 per Meter
# 1378  False ❌ The price is 1930.6930693069307 per Meter
#
# [1379 rows x 3 columns]
